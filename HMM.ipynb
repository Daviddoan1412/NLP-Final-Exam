# %% [markdown]
# ## Hidden Markov Model

# %%
# !git clone https://github.com/VinAIResearch/PhoNER_COVID19.git
# Out:
# Cloning into 'PhoNER_COVID19'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 44 (delta 14), reused 30 (delta 12), pack-reused 0
# Unpacking objects: 100% (44/44), done.

# %%
tagset = set()
with open('/content/PhoNER_COVID19/data/syllable/train_syllable.conll') as f:
    for line in f:
        wordtags = line.split()
        if(len(wordtags)>0):
          tag = wordtags[-1]
          tagset.add(tag)

# %%
print('# Number of tags: %d' % len(tagset))
print(tagset)
# Out:
# # Number of tags: 21
# {'B-NAME', 'I-DATE', 'I-JOB', 'B-DATE', 'I-PATIENT_ID', 'B-ORGANIZATION', 'B-JOB', 'I-AGE', 'B-LOCATION', 'B-PATIENT_ID', 'I-SYMPTOM_AND_DISEASE', 'B-TRANSPORTATION', 'B-GENDER', 'B-SYMPTOM_AND_DISEASE', 'I-ORGANIZATION', 'I-GENDER', 'I-TRANSPORTATION', 'I-NAME', 'B-AGE', 'O', 'I-LOCATION'}

# %%
def load_data(directory):
  sentence = []
  res = []
  with open(directory) as f:
    for lines in f:
      lines = lines.strip()
      if(lines==""):
        res.append(sentence)
        sentence = []
      else:
        word = lines.split(" ")[0]
        label = lines.split(" ")[1]
        sentence.append((word, label))
  return res

# %%
test_data = load_data("/content/PhoNER_COVID19/data/syllable/test_syllable.conll")

# %%
from collections import defaultdict

def train(train_file: str, model_file: str):
    emit = defaultdict(int)   # dictionary to store emission count C(t_i, w_i)
    transition = defaultdict(int)   # transition count C(t_{i-1}, t_i)
    context = defaultdict(int)  # count the context
    with open(train_file, 'r') as f:
        previous = '<s>'
        for line in f:
            line = line.strip()

            if(line==''):
              transition[previous + ' </s>'] += 1
              previous = '<s>'    # Make the sentence start
              context[previous] += 1
            else:
              wordtags = line.split()
              word, tag = wordtags[0], wordtags[1]
              transition[previous + ' ' + tag] += 1   # Count the transition
              context[tag] += 1   # Count the context
              emit[tag + ' ' + word] += 1   # Count the emission
              previous = tag

    # Now we will save the parameters of the model to a file
    with open(model_file, 'w') as fo:

        # Save transition probabilities
        for key, value in transition.items():
            previous, word = key.split(' ')
            fo.write('T %s %f\n' % (key, value/context[previous]))

        # Save emission probabilities
        for key, value in emit.items():
            tag, word = key.split(' ')
            fo.write('E %s %f\n' % (key, value/context[tag]))

    print('Finished training first-order HMM!')

# %%
train('/content/PhoNER_COVID19/data/syllable/train_syllable.conll', '/content/HMM_model.txt')
# Out:
# Finished training first-order HMM!

# %%
def load_model(model_file: str):
    """Load saved HMM model
    """
    transition = defaultdict(lambda: 0)
    emission = defaultdict(lambda: 0)
    possible_tags = {}
    
    with open(model_file, 'r') as f:
        for line in f:
            line = line.strip()
            _type, context, word, prob = line.split(' ')
            prob = float(prob)
            possible_tags[context] = 1  # # We use this to enumerate all tags
            if _type == 'T':
                transition[context + ' ' + word] = prob
            else:
                emission[context + ' ' + word] = prob
    return transition, emission, possible_tags

# %%
transition, emission, possible_tags = load_model('HMM_model.txt')
print( list(possible_tags.keys()) )
print(transition)
print(emission)
# Out:
# ['<s>', 'O', 'B-ORGANIZATION', 'I-ORGANIZATION', 'B-SYMPTOM_AND_DISEASE', 'I-SYMPTOM_AND_DISEASE', 'B-LOCATION', 'I-LOCATION', 'B-DATE', 'B-PATIENT_ID', 'B-AGE', 'B-NAME', 'I-DATE', 'B-JOB', 'I-JOB', 'B-TRANSPORTATION', 'B-GENDER', 'I-GENDER', 'I-TRANSPORTATION', 'I-NAME', 'I-AGE', 'I-PATIENT_ID']
# defaultdict(<function load_model.<locals>.<lambda> at 0x7faa12da70e0>, {'<s> O': 0.946489, 'O O': 0.843383, 'O B-ORGANIZATION': 0.007436, 'B-ORGANIZATION I-ORGANIZATION': 0.983289, 'I-ORGANIZATION I-ORGANIZATION': 0.767954, 'I-ORGANIZATION O': 0.230178, 'O </s>': 0.038345, 'O B-SYMPTOM_AND_DISEASE': 0.011014, 'B-SYMPTOM_AND_DISEASE I-SYMPTOM_AND_DISEASE': 0.762335, 'I-SYMPTOM_AND_DISEASE O': 0.482819, 'O B-LOCATION': 0.040903, 'B-LOCATION O': 0.073731, 'B-LOCATION I-LOCATION': 0.919785, 'I-LOCATION I-LOCATION': 0.596637, 'I-LOCATION O': 0.401332, 'O B-DATE': 0.019686, 'B-DATE O': 0.508042, 'O B-PATIENT_ID': 0.025004, 'B-PATIENT_ID O': 0.991358, 'O B-AGE': 0.004869, 'B-AGE O': 0.997067, 'B-PATIENT_ID B-NAME': 0.003395, 'B-NAME O': 0.853868, 'B-DATE I-DATE': 0.490781, 'I-DATE I-DATE': 0.4996, 'I-DATE O': 0.4964, 'O B-JOB': 0.001183, 'B-JOB I-JOB': 0.990244, 'I-JOB O': 0.493711, 'I-SYMPTOM_AND_DISEASE I-SYMPTOM_AND_DISEASE': 0.51674, 'O B-TRANSPORTATION': 0.001731, 'B-TRANSPORTATION O': 0.725664, 'O B-GENDER': 0.004089, 'B-GENDER O': 0.839483, 'B-GENDER I-GENDER': 0.02583, 'I-GENDER O': 0.214286, 'B-SYMPTOM_AND_DISEASE O': 0.231411, 'I-JOB I-JOB': 0.361635, 'B-TRANSPORTATION I-TRANSPORTATION': 0.252212, 'I-TRANSPORTATION O': 0.826087, 'I-ORGANIZATION B-NAME': 0.000415, 'B-NAME I-NAME': 0.126074, 'I-NAME I-NAME': 0.45, 'I-NAME O': 0.4875, '<s> B-ORGANIZATION': 0.031828, 'B-GENDER B-JOB': 0.073801, 'O B-NAME': 0.002357, 'B-LOCATION </s>': 0.006484, 'I-ORGANIZATION B-LOCATION': 0.000208, 'I-ORGANIZATION </s>': 0.00083, 'I-JOB B-ORGANIZATION': 0.022013, '<s> B-LOCATION': 0.015715, 'I-LOCATION </s>': 0.001219, 'I-NAME </s>': 0.0625, 'B-SYMPTOM_AND_DISEASE B-SYMPTOM_AND_DISEASE': 0.006254, '<s> B-NAME': 0.001989, 'I-LOCATION B-LOCATION': 0.000569, 'I-JOB B-AGE': 0.034591, 'I-DATE B-LOCATION': 0.0016, 'B-ORGANIZATION O': 0.016711, 'B-DATE B-SYMPTOM_AND_DISEASE': 0.000392, 'B-GENDER B-AGE': 0.055351, 'B-NAME B-SYMPTOM_AND_DISEASE': 0.008596, 'B-TRANSPORTATION B-LOCATION': 0.022124, 'I-JOB B-NAME': 0.050314, '<s> B-GENDER': 0.002188, 'B-AGE I-AGE': 0.002933, 'I-AGE O': 1.0, 'B-PATIENT_ID I-PATIENT_ID': 0.001852, 'I-PATIENT_ID I-PATIENT_ID': 0.6, 'I-PATIENT_ID O': 0.333333, 'I-DATE B-ORGANIZATION': 0.002, 'I-JOB B-LOCATION': 0.031447, 'I-GENDER B-AGE': 0.785714, 'B-PATIENT_ID B-JOB': 0.002778, '<s> B-PATIENT_ID': 0.000796, 'B-PATIENT_ID </s>': 0.000309, 'I-JOB B-GENDER': 0.003145, 'I-TRANSPORTATION I-TRANSPORTATION': 0.173913, '<s> B-SYMPTOM_AND_DISEASE': 0.000199, '<s> B-JOB': 0.000597, 'B-GENDER B-NAME': 0.005535, 'I-ORGANIZATION B-TRANSPORTATION': 0.000415, 'B-DATE B-ORGANIZATION': 0.000392, 'I-DATE </s>': 0.0004, 'I-LOCATION B-DATE': 8.1e-05, 'B-NAME </s>': 0.011461, 'I-SYMPTOM_AND_DISEASE </s>': 0.000441, '<s> B-DATE': 0.000199, 'B-JOB O': 0.009756, 'I-LOCATION B-ORGANIZATION': 8.1e-05, 'B-DATE B-NAME': 0.000392, 'I-PATIENT_ID B-ORGANIZATION': 0.066667, 'B-PATIENT_ID B-GENDER': 0.000309, 'I-JOB B-PATIENT_ID': 0.003145, 'I-LOCATION B-NAME': 8.1e-05})
# defaultdict(<function load_model.<locals>.<lambda> at 0x7faa12da7170>, {'O Đồng': 5.4e-05, 'O thời': 0.001716, 'O ,': 0.082216, 'O bệnh': 0.043871, 'O viện': 0.005202, 'O tiếp': 0.006786, 'O tục': 0.001368, 'O thực': 0.000665, 'O hiện': 0.003679, 'O các': 0.004661, 'O biện': 0.00017, 'O pháp': 0.000271, 'O phòng': 0.000928, 'O chống': 0.000309, 'O dịch': 0.002466, 'O COVID': 0.003563, 'O -': 0.012336, 'O 19': 0.005859, 'O theo': 0.001824, 'O hướng': 0.000216, 'O dẫn': 0.000294, 'O của': 0.00538, 'B-ORGANIZATION Bộ': 0.26737, 'I-ORGANIZATION Y': 0.080116, 'I-ORGANIZATION tế': 0.080946, 'O .': 0.038213, 'O "': 0.013673, 'O Số': 6.2e-05, 'O có': 0.013348, 'O thể': 0.00119, 'O nhận': 0.003896, 'O nhân': 0.039605, 'O bị': 0.001762, 'B-SYMPTOM_AND_DISEASE sốt': 0.165393, 'I-SYMPTOM_AND_DISEASE cao': 0.009251, 'O và': 0.013511, 'B-SYMPTOM_AND_DISEASE khó': 0.076442, 'I-SYMPTOM_AND_DISEASE thở': 0.049339, 'O đang': 0.003045, 'O giảm': 0.000162, 'O dần': 7e-05, 'O thông': 0.001623, 'O cáo': 0.000294, 'O đoạn': 0.000278, 'O cảnh': 0.001724, 'O báo': 0.001306, 'O những': 0.002048, 'O này': 0.004042, 'O thay': 0.000139, 'O vào': 0.002674, 'O đó': 0.005264, 'O được': 0.012228, 'O chuyển': 0.003517, 'O tới': 0.000974, 'O khám': 0.001384, 'O khẩn': 0.000147, 'O cấp': 0.000572, 'O khiến': 0.000108, 'O mắc': 0.001747, 'O hiểm': 0.0001, 'O nghèo': 8e-06, 'O khác': 0.001059, 'O không': 0.003841, 'O cơ': 0.001407, 'O hội': 0.000495, 'O điều': 0.007126, 'O trị': 0.006276, 'O Ngoài': 0.000348, 'O ra': 0.001755, 'O người': 0.011014, 'O xúc': 0.004375, 'O gián': 3.1e-05, 'O (': 0.006748, 'O đã': 0.007768, 'O gặp': 0.000271, 'O gần': 0.00228, 'O với': 0.009151, 'O )': 0.006748, 'O lập': 0.000247, 'O danh': 0.000193, 'O sách': 0.000201, 'O yêu': 0.000371, 'O cầu': 0.000402, 'O cách': 0.007822, 'O ly': 0.007567, 'O y': 0.002172, 'O tế': 0.002211, 'O tại': 0.013086, 'O nơi': 0.001499, 'O ở': 0.008394, 'O Bà': 0.000286, 'O khi': 0.004514, 'O trở': 0.001206, 'O về': 0.005132, 'O quá': 0.000696, 'B-LOCATION Doha': 0.000371, 'B-LOCATION Qatar': 0.001667, 'O đáp': 7e-05, 'O xuống': 0.000147, 'B-LOCATION Tân': 0.002038, 'I-LOCATION Sơn': 0.010074, 'I-LOCATION Nhất': 0.00325, 'O sáng': 0.001252, 'B-DATE 2/3': 0.010592, 'O cùng': 0.002543, 'O 75': 1.5e-05, 'O hành': 0.00075, 'O khách': 0.001128, 'O trong': 0.005186, 'O 55': 5.4e-05, 'O nước': 0.001206, 'O ngoài': 0.000935, 'O Bệnh': 0.005565, 'B-PATIENT_ID 523': 0.003395, 'O chồng': 0.000495, 'O là': 0.009607, 'B-PATIENT_ID 522': 0.003086, 'B-AGE 67': 0.010264, 'O tuổi': 0.006639, 'O ghi': 0.002442, 'O nhiễm': 0.003787, 'O nCoV': 0.003811, 'O hôm': 0.001128, 'B-DATE 31/7': 0.011377, 'O Trường': 0.000255, 'O hợp': 0.002937, 'B-PATIENT_ID 188': 0.00679, 'B-NAME L.T.H.': 0.017192, 'O tin': 0.001213, 'O từ': 0.007366, 'O quan': 0.002126, 'O địa': 0.001499, 'O phương': 0.000557, 'O nhà': 0.002945, 'O ngày': 0.012568, 'B-DATE 14': 0.018439, 'I-DATE -': 0.4956, 'I-DATE 4': 0.0612, 'O chỉ': 0.002149, 'O con': 0.00085, 'O đây': 0.000928, 'O phải': 0.001507, 'O tái': 0.000356, 'O mà': 0.000286, 'O do': 0.001368, 'O virus': 0.001113, 'O yếu': 0.000286, 'O điểm': 0.000719, 'O lấy': 0.003115, 'O mẫu': 0.003911, 'O lần': 0.003061, 'O trước': 0.001368, 'O hoặc': 0.000502, 'O vị': 0.000193, 'O trí': 0.000162, 'O đến': 0.008595, 'O âm': 0.003362, 'O tính': 0.010025, 'O giả': 0.0001, 'O Riêng': 0.000232, 'B-PATIENT_ID 91': 0.032716, 'B-JOB phi': 0.195122, 'I-JOB công': 0.13522, 'O Anh': 0.001469, 'O ngụ': 0.000247, 'B-LOCATION quận': 0.047054, 'I-LOCATION 2': 0.01438, 'B-LOCATION TP.': 0.023527, 'I-LOCATION HCM': 0.021448, 'O liên': 0.001932, 'O ổ': 0.000286, 'B-LOCATION quán': 0.005187, 'I-LOCATION bar': 0.001625, 'I-LOCATION Buddha': 0.002762, 'O cập': 2.3e-05, 'O nhật': 5.4e-05, 'B-DATE 10': 0.018046, 'O cho': 0.005789, 'O biết': 0.002164, 'O diễn': 0.000402, 'O biến': 0.000765, 'O xấu': 0.000116, 'O hơn': 0.000819, 'O nhưng': 0.000958, 'O cũng': 0.00184, 'O chưa': 0.000982, 'O dấu': 0.000371, 'O hiệu': 0.000572, 'O hồi': 0.00 ...

# %%
import math


def viterbi(line, transition, emission, possible_tags):
    """Infer the tag sequence for a tokenized sentence

    Args:
        line (str): a tokenized word sequence
                    e.g., "Chiều cuối thu , trời vùng_biển Nghi_Xuân ảm_đạm ."
        transition (dict): transition probabilities
        emission (dict): emission probabilities
    """
    words = line.split()
    l = len(words)
    best_score = {}
    best_edge = {}
    best_score[('0 <s>')] = 0  # Start with <s>
    best_edge[('0 <s>')] = None

    K = frozenset(possible_tags.keys())
    K0 = frozenset(['<s>'])
    # Forward Step
    for i in range(l):
        tagset_prev, tagset_next = K, K
        if i == 0:
            tagset_prev = K0
        for prev in tagset_prev:
            for _next in tagset_next:
                if str(i) + ' ' + prev in best_score and prev + ' ' + _next in transition:
                    if emission[_next + ' ' + words[i]] == 0:
                        # To avoid zero probabilities, we use very small value
                        emission[_next + " " + words[i]] = 10 ** (-10)
                    
                    score = best_score[str(i) + ' ' + prev] + (-math.log(transition[prev + ' ' + _next])) + (-math.log(emission[_next + ' ' + words[i]]))

                    if str(i + 1) + " " + _next not in best_score or best_score[str(i + 1) + " " + _next] > score:
                        best_score[str(i + 1) + " " + _next] = score
                        best_edge[str(i + 1) + " " + _next] = str(i) + " " + prev
    
    tagset_prev = K
    if l == 0:
        tagset_prev = K0
    for prev in tagset_prev:
        if str(l) + ' ' + prev in best_score:
            if (prev + ' ' + '</s>') not in transition:
                transition[prev + ' ' + '</s>'] = 10 ** (-10)
            
            # Calculate best_score[str(l+1) + ' </s>'] and best_edge[str(l+1) + ' </s>'] 
            # for the sentence top symbole '</s>'
            # The different from the other time step is that, we do not use emission probility in calculating score
            score = best_score[str(l) + ' ' + prev] + (-math.log(transition[prev + ' ' + '</s>']))
            if str(l+1) + ' ' + '</s>' not in best_score or best_score[str(l+1) + ' </s>'] > score:
                best_score[str(l+1) + ' </s>'] = score
                best_edge[str(l+1) + ' </s>'] = str(l) + ' ' + prev
    
    # Backward Step
    tags = []
    next_edge = best_edge[str(l + 1) + " " + "</s>"]
    # TODO: Complete the backward step in Viterbi algorithm
    # Finish the while loop in the pseudo code
    while next_edge != "0 <s>":
        position, tag= next_edge.split()
        tags.append(tag)
        next_edge = best_edge[next_edge]
    
    # END OF YOUR CODE
    tags.reverse()
    return ' '.join(tags)

# %%
viterbi('Xin mơi nghe hướng dẫn của Bộ Y tế .   ', transition, emission, possible_tags)
# Out:
# 'O O O B-JOB I-JOB O B-ORGANIZATION I-ORGANIZATION I-ORGANIZATION O'

# %%
with open('output.txt', 'w') as f:
    for i in range(len(test_data)):
        for j in range(len(test_data[i])):
          f.write(test_data[i][j][0]+' '+test_data[i][j][1]+'\n')
        f.write('\n')

# %%
with open('answer.txt', 'w') as f:
    for i in range(len(test_data)):
      X_test = test_data[i]
      sentence = ''
      for wordtags in X_test:
        sentence += wordtags[0]+' '
      y_pred = viterbi(sentence,transition, emission, possible_tags).split(' ')

      for j in range(len(test_data[i])):
           f.write(test_data[i][j][0]+' '+y_pred[j]+'\n')
      f.write('\n')

# %%
# !pip install seqeval[cpu]
from seqeval.metrics import precision_score, recall_score, f1_score

def get_tags(filepath):
    res = []
    with open(filepath, 'r') as f:
        cur_sen = []
        for line in f:
            line = line.strip()
            if line == '':
                if len(cur_sen) != 0:
                    res.append(cur_sen)
                    cur_sen = []
            else:
                word, tag = line.split()
                cur_sen.append(tag)
    if len(cur_sen) != 0:
        res.append(cur_sen)
    return res

def evaluate(test_file, output_file):
    y_true = get_tags(test_file)
    y_pred = get_tags(output_file)

    p = precision_score(y_true, y_pred)
    r = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    return p, r, f1
# Out:
# Collecting seqeval[cpu]
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.1 MB/s
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from seqeval[cpu]) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.7/dist-packages (from seqeval[cpu]) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval[cpu]) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval[cpu]) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.21.3->seqeval[cpu]) (1.1.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=f466b7653e6e757f9b3bf230c42894824d378cca33212e74bef88485d7fbead5
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
evaluate('./answer.txt', './output.txt')
# Out:
# (0.735832978270132, 0.7359584079093157, 0.7358956877450146)
